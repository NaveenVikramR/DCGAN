# %% [markdown]
# # Phase 0 — Environment Setup & GPU Check
#
# Run this notebook first in Colab/Kaggle to confirm the runtime is ready before moving to data/model/training phases.

# %%
# !pip install -q pytorch-fid kagglehub

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device:", torch.cuda.get_device_name(0))
assert torch.cuda.is_available(), "No GPU detected — switch the Colab/Kaggle runtime to GPU (T4)."
# Out:
# CUDA available: True
# Device: Tesla T4

# %%
# Clone the repo (replace with your GitHub URL once pushed) and add src/ to the path
import sys
sys.path.append("/content/dcgan/src")  # adjust path after cloning/uploading the repo
